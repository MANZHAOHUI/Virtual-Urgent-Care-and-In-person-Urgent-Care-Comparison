# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series

df = pd.DataFrame(pd.read_csv('c:\data\Saif/vcc_689.csv'))
df.describe()
# Out:
#           Mdlive Id  Encounter Id         Age           Zip  Reporting1  \
# count  6.880000e+02  6.880000e+02  688.000000    688.000000         0.0
# mean   1.440832e+07  1.624563e+07   36.767442  27725.623547         NaN
# std    1.481366e+06  1.026450e+06   12.975668    365.931436         NaN
# min    1.176216e+07  1.394108e+07    1.000000  27020.000000         NaN
# 25%    1.309556e+07  1.539661e+07   28.750000  27523.750000         NaN
# 50%    1.442884e+07  1.638324e+07   36.000000  27597.000000         NaN
# 75%    1.568840e+07  1.711229e+07   46.000000  27807.500000         NaN
# max    1.706662e+07  1.782545e+07   76.000000  28806.000000         NaN
#
#        Reporting2  Reporting3  Reporting4  Customer Wait Time  \
# count         0.0         0.0         0.0          688.000000
# mean          NaN         NaN         NaN            7.250000
# std           NaN         NaN         NaN           14.069023
# min           NaN         NaN         NaN            0.000000
# ...

# %%
df.drop_duplicates(subset=['Encounter Id'],keep='first',inplace=True)
df.describe()
# Out:
#           Mdlive Id  Encounter Id          Age           Zip  Reporting1  \
# count  1.260000e+03  1.260000e+03  1260.000000   1260.000000         0.0
# mean   1.440605e+07  1.623306e+07    36.930952  27738.280159         NaN
# std    1.438481e+06  1.000474e+06    13.422119    389.783160         NaN
# min    1.176216e+07  1.394108e+07     0.000000  27012.000000         NaN
# 25%    1.312971e+07  1.543660e+07    28.000000  27523.750000         NaN
# 50%    1.457961e+07  1.629100e+07    37.000000  27603.000000         NaN
# 75%    1.560896e+07  1.705402e+07    47.000000  27856.000000         NaN
# max    1.707877e+07  1.783225e+07    76.000000  28806.000000         NaN
#
#        Reporting2  Reporting3  Reporting4  Customer Wait Time  \
# count         0.0         0.0         0.0         1260.000000
# mean          NaN         NaN         NaN            7.684921
# std           NaN         NaN         NaN           16.809589
# ...

# %%
df.to_csv('c:\data\Saif/vcc_1260.csv', index=False)
